# %% [markdown]
# # Imports

# %%
import sys
sys.path.insert(0, '..')

import ast
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle
from matplotlib.lines import Line2D
from matplotlib import rcParams
from scipy import stats
from tqdm import tqdm

from DB_connection import DB_connection
from diversity_metrics import compute_user_shanon_entropy
from data.base_mnl_a import entropy_active_users_15_15 as shanon_entropy_dict
from data.base_mnl_a import bases_active_users_15_15 as  bases_dict
from recommendation_system import MatrixFactorizationRecommender



db_connection = DB_connection()
active_users  =  db_connection.get_active_users(15,15)

matrix_factorization_RS = MatrixFactorizationRecommender(19)
matrix_factorization_RS.fit()

# %% [markdown]
# # Usefull functions

# %%
def show_all_simulations_for_one_user(user_id,simulation_type, parameters_id= None, nbr_simulation_wanted = None):
       if parameters_id == None:
              query = f'''SELECT MAX(simulation_number) FROM simulated_behaviors 
              WHERE user_id = '{user_id}'
              AND simulation_type = '{simulation_type}';'''

       else:
              query = f'''SELECT MAX(simulation_number) FROM simulated_behaviors 
                     WHERE user_id = '{user_id}'
                     AND simulation_type = '{simulation_type}'
                     AND parameters_id = '{parameters_id}'; '''
       try:
              nbr_simulations = db_connection.select_single_value(query)
       except:
              nbr_simulations = 1
       if nbr_simulation_wanted is None:
              nbr_simulations = 1
       diversity_simulations = []
       if nbr_simulations != None:
              for i in range(1,nbr_simulations+1):
                     query = f'''SELECT * FROM simulated_behaviors 
                            WHERE user_id = '{user_id}'
                            AND simulation_type = '{simulation_type}'
                            AND simulation_number ={i} ; '''
                     simulation = db_connection.select(query)
                     diversity_simulations.append(list(simulation['diversity'])[0:30])
       
       return diversity_simulations

def mean_diversity_all_users(users_quadrant,simulation_type, parameters = None):
    all_simulations_mmr = []
    for user in users_quadrant:
        all_user_simulations = show_all_simulations_for_one_user(user,simulation_type, parameters_id=parameters)
        for simulation in all_user_simulations:
            if len(simulation)>0:
                all_simulations_mmr.append(simulation)

    all_simulations_array = np.array(all_simulations_mmr)
    mean_diversity = []
    for i in range(len(all_simulations_array[0])):
        mean_diversity.append(np.mean(all_simulations_array[:,i]))
    return mean_diversity

def diversity_all_users(users_quadrant,simulation_type, parameters = None):
    all_simulations_mmr = []
    for user in users_quadrant:
        all_user_simulations = show_all_simulations_for_one_user(user,simulation_type, parameters_id=parameters)
        for simulation in all_user_simulations:
            if len(simulation)>0:
                all_simulations_mmr.append(simulation)

    all_simulations_array = np.array(all_simulations_mmr)
    return all_simulations_array

def get_final_diversity(users_quadrant,simulation_type, parameters = None):
    all_simulations_mmr = []
    for user in users_quadrant:        
        all_user_simulations = show_all_simulations_for_one_user(user,simulation_type, parameters_id=parameters)
        for simulation in all_user_simulations:
            if len(simulation)>0:
                all_simulations_mmr.append(simulation)

    all_simulations_array = np.array(all_simulations_mmr)
    return all_simulations_array[:,-1]

def get_initial_diversity(users_quadrant,simulation_type, parameters = None):
    all_simulations_mmr = []
    for user in users_quadrant:
        all_user_simulations = show_all_simulations_for_one_user(user,simulation_type, parameters_id=parameters)
        for simulation in all_user_simulations:
            if len(simulation)>0:
                all_simulations_mmr.append(simulation)
            
    all_simulations_array = np.array(all_simulations_mmr)
    return all_simulations_array[:,0]

def plot_with_confidence_interval(data,color='blue',label = None, ls = None):
    mean_diversity = np.mean(data, axis=0)
    confidence_interval = stats.sem(data, axis=0) #* 1.96  # For 95% confidence interval

    # Plot the mean diversity
    x = np.arange(data.shape[1])  # x-axis (columns of the array)
    plt.plot(x, mean_diversity, label=label, color=color, ls = ls)

    # Add confidence intervals
    plt.fill_between(x, mean_diversity - confidence_interval, 
                    mean_diversity + confidence_interval, 
                    color=color, alpha=0.2)
    
def compute_recommendation_diversity_for_one_user(user_id,simulation_type, parameters_id= None):

    if parameters_id == None:
        query = f'''SELECT * FROM simulated_behaviors 
                    WHERE user_id = '{user_id}'
                    AND simulation_type = '{simulation_type}'
                    AND simulation_number =1 ; '''
    else:
        query = f'''SELECT * FROM simulated_behaviors 
                    WHERE user_id = '{user_id}'
                    AND simulation_type = '{simulation_type}'
                    AND simulation_number =1
                    AND parameters_id = '{parameters_id}'; '''
    simulation = db_connection.select(query)
    all_recommended_items = []
    for ri in list(simulation['recommended_items']):
        all_recommended_items = all_recommended_items + ast.literal_eval(ri)[0:-1]
    all_recommended_items = [str(i) for i in all_recommended_items]
    return compute_user_shanon_entropy(all_recommended_items)

def recommendation_diversity_all_users(users_quadrant,simulation_type, parameters = None):
    recommendation_diversities = []
    for user in users_quadrant:
        recommendation_diversities.append(compute_recommendation_diversity_for_one_user(user,simulation_type,parameters))
    return recommendation_diversities

def get_proba_no_choice_for_one_user(user_id,simulation_type, parameters_id = None, nbr_simulation_wanted = None):
    if parameters_id == None:
        query = f'''SELECT MAX(simulation_number) FROM simulated_behaviors 
                      WHERE user_id = '{user_id}'
                      AND simulation_type = '{simulation_type}';'''

    else:
        query = f'''SELECT MAX(simulation_number) FROM simulated_behaviors 
                     WHERE user_id = '{user_id}'
                     AND simulation_type = '{simulation_type}'
                     AND parameters_id = '{parameters_id}'; '''

    nbr_simulations = db_connection.select_single_value(query)
       #print(nbr_simulations)
    
    if nbr_simulation_wanted is None:
        nbr_simulations = 1
    
    mean_no_choice_prob = 0
    n = 0
    if nbr_simulations != None:
        for i in range(1,1+nbr_simulations):
            query = f'''SELECT * FROM simulated_behaviors 
                            WHERE user_id = '{user_id}'
                            AND simulation_type = '{simulation_type}'
                            AND simulation_number ={i} ; '''
            simulation = db_connection.select(query)
            for probabilities in simulation['probabilities']:
                proba = ast.literal_eval(probabilities)
                mean_no_choice_prob += proba[-1]
                n = n +1
    
        return mean_no_choice_prob/n

def no_choice_prob(users_quadrant,simulation_type, parameters = None):
    quadrant_mean_no_choice_prob = []
    for user in (users_quadrant):
        no_choice_prob = get_proba_no_choice_for_one_user(user,simulation_type,parameters)
        if no_choice_prob != None:
            quadrant_mean_no_choice_prob.append(no_choice_prob)
    return quadrant_mean_no_choice_prob

def mean_no_choice_prob(users_quadrant,simulation_type, parameters = None):
    quadrant_mean_no_choice_prob = []
    for user in (users_quadrant):
        no_choice_prob = get_proba_no_choice_for_one_user(user,simulation_type,parameters)
        if no_choice_prob != None:
            quadrant_mean_no_choice_prob.append(no_choice_prob)
    return np.mean(quadrant_mean_no_choice_prob)

def sigmoid(x):
    return 1 / (1 + np.exp(-x))

def get_initial_score_for_one_user(user_id,simulation_type,matrix_factorization_RS, parameters_id = None):
    if parameters_id == None:
        query = f'''SELECT MAX(simulation_number) FROM simulated_behaviors 
                      WHERE user_id = '{user_id}'
                      AND simulation_type = '{simulation_type}';'''

    else:
        query = f'''SELECT MAX(simulation_number) FROM simulated_behaviors 
                     WHERE user_id = '{user_id}'
                     AND simulation_type = '{simulation_type}'
                     AND parameters_id = '{parameters_id}'; '''

    nbr_simulations = db_connection.select_single_value(query)
   
    all_ratings = []
    if nbr_simulations != None:
        for i in range(1,1+1):
            query = f'''SELECT * FROM simulated_behaviors 
                            WHERE user_id = '{user_id}'
                            AND simulation_type = '{simulation_type}'
                            AND simulation_number ={i}; '''
            simulation = db_connection.select(query)
            for i in range(len(simulation['recommended_items'])):
                recom_items = ast.literal_eval(simulation['recommended_items'][i])
                chosen_item = simulation['chosen_item'][i]
                for item in recom_items:
                    if item != 'No_choice':
                        rating = matrix_factorization_RS.predict_rating(user_id,item)
                        rating = sigmoid(rating)
                        all_ratings.append(rating)
        return np.mean(all_ratings)
                
def initial_scores_for_users(users_quadrant,simulation_type, parameters = None):
    matrix_factorization_RS = MatrixFactorizationRecommender(100)
    matrix_factorization_RS.fit()
    initial_score = []
    for user in users_quadrant:
        score = get_initial_score_for_one_user(user,simulation_type,matrix_factorization_RS,parameters)
        if score != None:
            initial_score.append(score)
    return initial_score

def mean_initial_scores_for_users(users_quadrant,simulation_type, parameters = None):
    matrix_factorization_RS = MatrixFactorizationRecommender(100)
    matrix_factorization_RS.fit()
    mean_initial_score = []
    for user in users_quadrant:
        score = get_initial_score_for_one_user(user,simulation_type,matrix_factorization_RS)
        if score != None:
            mean_initial_score.append(score)
    return np.mean(mean_initial_score)


def confidence_interval_2D(x, y, ax, whis=1.5, color=None, label=None,xlabel = None, ylabel = None):
    # Ensure x and y are NumPy arrays
    x = np.asarray(x)
    y = np.asarray(y)


    mean_x = np.mean(x, axis=0)
    CI_x = stats.sem(x, axis=0) * 1.96

    mean_y = np.mean(y, axis=0)
    CI_y = stats.sem(y, axis=0)* 1.96
    
    ax.plot([mean_x], [mean_y], color=color, marker='o', markersize = 10)

    box = Rectangle(
        (mean_x - CI_x, mean_y-CI_y), 2*CI_x, 2*CI_y,
        edgecolor=color,
        facecolor=color,
        alpha=0.4,
        zorder=0,
        label=label  # Add the label here for the legend
    )
    ax.add_patch(box)

        ## The x median
    vline = Line2D(
       [ mean_x,mean_x], [mean_y -CI_y, mean_y +CI_y],
        color=color,
        zorder=1
    )
    ax.add_line(vline)

    ## The y median
    hline = Line2D(
        [mean_x-CI_x, mean_x + CI_x], [mean_y, mean_y],
        color=color,
        zorder=1
    )
    ax.add_line(hline)

    
    

    ax.set_xlabel(xlabel,fontsize = 14)
    ax.set_ylabel(ylabel, fontsize =14)

# %% [markdown]
# # Quadrant definition

# %%
Q1 = []
Q2 = []
Q3 = []
Q4 = []
mat = np.zeros((2,2))
for user in active_users:
    E = shanon_entropy_dict[user]
    a = bases_dict[user]
    E_threshold = 0.65
    a_threshold_max = 12
    a_threshold_min = 12


    if a<a_threshold_max and E<E_threshold:
        mat[0][0] += 1
        Q1.append(user)
    elif a<a_threshold_max and E>E_threshold:
        mat[0][1] += 1
        Q2.append(user)
    elif a>a_threshold_min and E<E_threshold:
        mat[1][0] += 1
        Q3.append(user)
    elif a>a_threshold_min and E>E_threshold:
        mat[1][1] += 1
        Q4.append(user)

# %% [markdown]
# # 1. Diversity

# %% [markdown]
# ## 1.1. Consumed Diversity

# %% [markdown]
# ### 1.1.1. Consumed Diversity change

# %%
diversity_change_svd = (get_final_diversity(active_users,'baseline') - get_initial_diversity(active_users,'baseline'))
diversity_change_mmr = get_final_diversity(active_users,'mmr', parameters='lambda_0.7') - get_initial_diversity(active_users,'mmr', parameters='lambda_0.7')
diversity_change_mmr_edc = (get_final_diversity(active_users,'mmr_exp_div_change','lambda_0.9') - get_initial_diversity(active_users,'mmr_exp_div_change','lambda_0.9'))
diversity_change_PI = (get_final_diversity(active_users,'adapt') - get_initial_diversity(active_users,'adapt'))

print("Mean diversity Changes")
print(f"Mean diversity change SVD: {np.mean(diversity_change_svd)}")
print(f"Mean diversity change SVD+MMR: {np.mean(diversity_change_mmr)}")
print(f"Mean diversity change SVD+MMR-EDC: {np.mean(diversity_change_mmr_edc)}")
print(f"Mean diversity change PI-adaptDiv: {np.mean(diversity_change_PI)}")
print(" ")

print("Pairwise statistical t-test")
print(f"p-value t-test between SVD and SVD+MMR: {stats.ttest_ind(diversity_change_mmr,diversity_change_svd).pvalue}")
print(f"p-value t-test between SVD+MMR and SVD+MMR-EDC: {stats.ttest_ind(diversity_change_mmr,diversity_change_mmr_edc).pvalue}")
print(f"p-value t-test between SVD+MMR and PI-adaptDiv: {stats.ttest_ind(diversity_change_mmr,diversity_change_PI).pvalue}")
print(f"p-value t-test between SVD+MMR-EDC and PI-adaptDiv: {stats.ttest_ind(diversity_change_PI,diversity_change_mmr_edc).pvalue}")
print(" ")

print("Test one sample, to test if the diversity change is bigger or smaller than 0")
print(f"Test one sample SVD : {stats.ttest_1samp(diversity_change_svd,0).pvalue}")
print(f"Test one sample SVD+MMR : {stats.ttest_1samp(diversity_change_mmr,0).pvalue}")
print(f"Test one sample SVD+MMR-EDC : {stats.ttest_1samp(diversity_change_mmr_edc,0).pvalue}")
print(f"Test one sample PI-adaptDiv : {stats.ttest_1samp(diversity_change_PI,0).pvalue}")

# %% [markdown]
# ### 1.1.2. Consumed Diversity evolution

# %% [markdown]
# ### All users

# %%
diversity_svd = diversity_all_users(active_users,'baseline')
print("baseline done")
diversity_mmr_exp = diversity_all_users(active_users,'mmr_exp_div_change',parameters = 'lambda_0.9')
print("mmr_exp_div_change done")
diversity_mmr = diversity_all_users(active_users,'mmr',parameters = 'lambda_0.9')
print("mmr done")   
diversity_PI = diversity_all_users(active_users,'adapt')

#div_mmr_lambda = []
#div_mmr_edc_lambda = []
#for i in range(2,10):
#   div_mmr_lambda.append(float(np.mean(get_final_diversity(active_users,'mmr', f'lambda_0.{i}'))))
#   div_mmr_edc_lambda.append(float(np.mean(get_final_diversity(active_users,'mmr_exp_div_change', f'lambda_0.{i}'))))


##### Plot #####

line_width = 2

xlabel_fontsize = 16  # Font size for x-axis labels
title_fontsize = 16   # Font size for titles
legend_fontsize = 16 
default_colors = rcParams['axes.prop_cycle'].by_key()['color']


plot_with_confidence_interval(diversity_svd, color=default_colors[0], label = 'SVD',ls='--')
plot_with_confidence_interval(diversity_mmr, color = default_colors[1], label = 'SVD + MMR', ls='-.')
plot_with_confidence_interval(diversity_mmr_exp, color=default_colors[2], label = 'SVD + MMR-EDC', ls =':')
plot_with_confidence_interval(diversity_PI, color = default_colors[3], label = 'PI-adaptDiv')


plt.xlabel('# Interactions (n)', fontsize=xlabel_fontsize)
plt.ylabel('Shannon Entropy : $D(H_n)$', fontsize=xlabel_fontsize)
plt.legend(fontsize= xlabel_fontsize)
# Out:
# baseline done
# mmr_exp_div_change done
# mmr done

# %% [markdown]
# ### By quadrants

# %%
mean_diversity_baseline_Q1 = mean_diversity_all_users(Q1,'baseline')
mean_diversity_baseline_Q2 = mean_diversity_all_users(Q2,'baseline')
mean_diversity_baseline_Q3 = mean_diversity_all_users(Q3,'baseline')
mean_diversity_baseline_Q4 = mean_diversity_all_users(Q4,'baseline')
print("baseline : Done")

mean_diversity_mmr_Q1 = mean_diversity_all_users(Q1,'mmr')
mean_diversity_mmr_Q2 = mean_diversity_all_users(Q2,'mmr')
mean_diversity_mmr_Q3 = mean_diversity_all_users(Q3,'mmr')
mean_diversity_mmr_Q4 = mean_diversity_all_users(Q4,'mmr')
print("mmr : Done")



mean_diversity_mmr_exp_Q1 = mean_diversity_all_users(Q1,'mmr_exp_div_change',parameters = 'lambda_0.9')
mean_diversity_mmr_exp_Q2 = mean_diversity_all_users(Q2,'mmr_exp_div_change',parameters = 'lambda_0.9')
mean_diversity_mmr_exp_Q3 = mean_diversity_all_users(Q3,'mmr_exp_div_change',parameters = 'lambda_0.9')
mean_diversity_mmr_exp_Q4 = mean_diversity_all_users(Q4,'mmr_exp_div_change',parameters = 'lambda_0.9')
print("mmr_exp : Done")


mean_diversity_adapt_Q1 = mean_diversity_all_users(Q1,'adapt')
mean_diversity_adapt_Q2 = mean_diversity_all_users(Q2,'adapt')
mean_diversity_adapt_Q3 = mean_diversity_all_users(Q3,'adapt')
mean_diversity_adapt_Q4 = mean_diversity_all_users(Q4,'adapt')
print("adapt : Done")


line_width = 3

fig, axs = plt.subplots(2, 2, figsize=(8, 8), sharex=True, sharey=False)

axs[0, 0].plot(mean_diversity_baseline_Q1, label = 'SVD', linewidth = line_width,  ls ='--')
axs[0, 0].plot(mean_diversity_mmr_Q1, label = 'SVD + MMR',linewidth = line_width,ls = '-.')
axs[0, 0].plot(mean_diversity_mmr_exp_Q1, label = 'SVD + MMR-EDC',linewidth = line_width, ls = ':')
axs[0, 0].plot(mean_diversity_adapt_Q1, label ='PI-adaptDiv',linewidth = line_width)
axs[0, 0].set_ylabel('Shannon Entropy : $D(H_n$)', fontsize=xlabel_fontsize)
axs[0, 0].set_title('Low Rigidity, Low Diversity', fontsize=title_fontsize)
axs[0, 0].set_ylim([0.5, 0.9])

axs[0, 1].plot(mean_diversity_baseline_Q2,linewidth = line_width, ls ='--')
axs[0, 1].plot(mean_diversity_mmr_Q2,linewidth = line_width,ls = '-.')
axs[0, 1].plot(mean_diversity_mmr_exp_Q2,linewidth = line_width,ls = ':')
axs[0, 1].plot(mean_diversity_adapt_Q2,linewidth = line_width)
axs[0, 1].set_title('Low Rigidity, High Diversity', fontsize=title_fontsize)
#axs[0, 1].set_title('a<12 and $D(H_0)$>0.65', fontsize=title_fontsize)
axs[0, 1].set_ylim([0.5, 0.9])

axs[1, 0].plot(mean_diversity_baseline_Q3,linewidth = line_width, ls ='--')
axs[1, 0].plot(mean_diversity_mmr_Q3,linewidth = line_width,ls = '-.')
axs[1, 0].plot(mean_diversity_mmr_exp_Q3,linewidth = line_width,ls = ':')
axs[1, 0].plot(mean_diversity_adapt_Q3,linewidth = line_width)
axs[1, 0].set_xlabel('# Interactions (n)', fontsize=xlabel_fontsize)
axs[1, 0].set_ylabel('Shannon Entropy : $D(H_n)$', fontsize=xlabel_fontsize)
axs[1, 0].set_title('High Rigidity, Low Diversity', fontsize=title_fontsize)
axs[1, 0].set_ylim([0.5, 0.9])

axs[1, 1].plot(mean_diversity_baseline_Q4,linewidth = line_width, ls ='--')
axs[1, 1].plot(mean_diversity_mmr_Q4,linewidth = line_width,ls = '-.')
axs[1, 1].plot(mean_diversity_mmr_exp_Q4,linewidth = line_width, ls = ':')
axs[1, 1].plot(mean_diversity_adapt_Q4,linewidth = line_width)
axs[1, 1].set_xlabel('# Interactions (n)', fontsize=xlabel_fontsize)
axs[1, 1].set_title('High Rigidity, High Diversity', fontsize=title_fontsize)
axs[1, 1].set_ylim([0.5, 0.9])

fig.legend(loc='upper right', bbox_to_anchor=(0.83, 1.05),fontsize= legend_fontsize,ncol = 2)
fig.align_ylabels()
# Out:
# baseline : Done
# mmr : Done
# mmr_exp : Done
# adapt : Done

# %% [markdown]
# ## 1.2. Recommended Diversity

# %%
recommendation_diversity_svd = recommendation_diversity_all_users(active_users,'baseline')
recommendation_diversity_mmr = recommendation_diversity_all_users(active_users,'mmr_exp_div_change',parameters = 'lambda_0.9')
recommendation_diversity_mmr_edc= recommendation_diversity_all_users(active_users,'mmr')
recommendation_diversity_PI_adaptDiv = recommendation_diversity_all_users(active_users,'adapt')

print(f"Average recommendation diversity SVD: {np.mean(recommendation_diversity_svd)}")
print(f"Average recommendation diversity SVD+MMR: {np.mean(recommendation_diversity_mmr)}")
print(f"Average recommendation diversity SVD+MMR-EDC: {np.mean(recommendation_diversity_mmr_edc)}")
print(f"Average recommendation diversity PI-adaptDiv: {np.mean(recommendation_diversity_PI_adaptDiv)}")
# Out:
# Average recommendation diversity SVD: 0.6121756733423781
# Average recommendation diversity SVD+MMR: 0.7960700625403179
# Average recommendation diversity SVD+MMR-EDC: 0.7654386793696716
# Average recommendation diversity PI-adaptDiv: 0.7064982456404011

# %% [markdown]
# # 2. Quality

# %% [markdown]
# ## 2.1. No choice probability

# %%
prob_no_choice_all_svd     = no_choice_prob(active_users,'baseline')
prob_no_choice_all_mmr     = no_choice_prob(active_users,'mmr', parameters='lambda_0.7')
prob_no_choice_all_mmr_edc = no_choice_prob(active_users,'mmr_exp_div_change', parameters='lambda_0.9')
prob_no_choice_all_adapt   = no_choice_prob(active_users,'adapt')

print(f"Average No-choice probability for SVD : {np.mean(prob_no_choice_all_svd)} ")
print(f"Average No-choice probability for SVD+MMR : {np.mean(prob_no_choice_all_mmr)} ")
print(f"Average No-choice probability for SVD+MMR-EDC : {np.mean(prob_no_choice_all_mmr_edc)} ")
print(f"Average No-choice probability for PI-adaptDiv : {np.mean(prob_no_choice_all_adapt)} ")

print(" ")

print(f"p-value between SVD+MMR and PI-adaptDiv : {stats.ttest_ind(prob_no_choice_all_mmr,prob_no_choice_all_adapt).pvalue}")
print(f"p-value between SVD+MMR-EDC and PI-adaptDiv : {stats.ttest_ind(prob_no_choice_all_adapt,prob_no_choice_all_mmr_edc).pvalue}")
print(f"p-value between SVD+MMR and SVD+MMR-EDC : {stats.ttest_ind(prob_no_choice_all_mmr,prob_no_choice_all_mmr_edc).pvalue}")
# Out:
# Average No-choice probability for SVD : 0.10832525084264587
# Average No-choice probability for SVD+MMR : 0.028321846403830685
# Average No-choice probability for SVD+MMR-EDC : 0.08184018323929729
# Average No-choice probability for PI-adaptDiv : 0.04856318869570905
#
# p-value between SVD+MMR and PI-adaptDiv : 0.0037973608122359864
# p-value between SVD+MMR-EDC and PI-adaptDiv : 2.5621397257276214e-07
# p-value between SVD+MMR and SVD+MMR-EDC : 1.069278404529135e-21

# %% [markdown]
# ## 2.2. Precision@10

# %% [markdown]
# ### 2.2.1. All users

# %%
qual_svd = initial_scores_for_users(active_users,'baseline')
qual_mmr =  initial_scores_for_users(active_users,'mmr')
qual_mmr_edc = initial_scores_for_users(active_users,'mmr_exp_div_change',f'lambda_0.9')
qual_PI = initial_scores_for_users(active_users,'adapt')



print(f"Precision@N SVD : {np.mean(qual_svd)}")
print(f"Precision@N SVD+MMR : {np.mean(qual_mmr)}")
print(f"Precision@N SVD+MMR-EDC : {np.mean(qual_mmr_edc)}")
print(f"Precision@N PI-adaptDiv : {np.mean(qual_PI)}")

print(f"p-value ttest between SVD+MMR and SVD+MMR-EDC: {stats.ttest_ind(qual_mmr,qual_mmr_edc).pvalue}")
print(f"p-value ttest between SVD+MMR and PI-adaptDiv: {stats.ttest_ind(qual_mmr,qual_PI).pvalue}")
print(f"p-value ttest between PI-adaptDiv and SVD+MMR-EDC: {stats.ttest_ind(qual_PI,qual_mmr_edc).pvalue}")
# Out:
# Precision@N SVD : 0.5194427539524328
# Precision@N SVD+MMR : 0.5173190873198412
# Precision@N SVD+MMR-EDC : 0.512522664921893
# Precision@N PI-adaptDiv : 0.5176605559971572
# p-value ttest between SVD+MMR and SVD+MMR-EDC: 5.349930333304661e-13
# p-value ttest between SVD+MMR and PI-adaptDiv: 0.6447769554108347
# p-value ttest between PI-adaptDiv and SVD+MMR-EDC: 1.0663363331073593e-14

# %% [markdown]
# ### 2.2.2. By quadrant

# %%
print("Q1")
mean = mean_initial_scores_for_users(Q1,'baseline')
print(f"Mean initial score SVD : {mean_initial_scores_for_users(Q1,'baseline')}")
print(f"Mean initial score MMR : {mean_initial_scores_for_users(Q1,'mmr','lambda_0.7')}")
print(f"Mean initial score MMR-EDC : {mean_initial_scores_for_users(Q1,'mmr_exp_div_change','lambda_0.9')}")
print(f"Mean initial score PI-adaptDiv : {mean_initial_scores_for_users(Q1,'adapt')}")

print("Q2")
mean = mean_initial_scores_for_users(Q2,'baseline')
print(f"Mean initial score SVD : {mean_initial_scores_for_users(Q2,'baseline')}")
print(f"Mean initial score MMR : {mean_initial_scores_for_users(Q2,'mmr','lambda_0.7')}")
print(f"Mean initial score MMR-EDC : {mean_initial_scores_for_users(Q2,'mmr_exp_div_change','lambda_0.9')}")
print(f"Mean initial score PI-adaptDiv : {mean_initial_scores_for_users(Q2,'adapt')}")

print("Q3")
mean = mean_initial_scores_for_users(Q3,'baseline')
print(f"Mean initial score SVD : {mean_initial_scores_for_users(Q3,'baseline')}")
print(f"Mean initial score MMR : {mean_initial_scores_for_users(Q3,'mmr','lambda_0.7')}")
print(f"Mean initial score MMR-EDC : {mean_initial_scores_for_users(Q3,'mmr_exp_div_change','lambda_0.9')}")
print(f"Mean initial score PI-adaptDiv : {mean_initial_scores_for_users(Q3,'adapt')}")

print("Q4")
mean = mean_initial_scores_for_users(Q4,'baseline')
print(f"Mean initial score SVD : {mean_initial_scores_for_users(Q4,'baseline')}")
print(f"Mean initial score MMR : {mean_initial_scores_for_users(Q4,'mmr','lambda_0.7')}")
print(f"Mean initial score MMR-EDC : {mean_initial_scores_for_users(Q4,'mmr_exp_div_change','lambda_0.9')}")
print(f"Mean initial score PI-adaptDiv : {mean_initial_scores_for_users(Q4,'adapt')}")
# Out:
# Q1
# Mean initial score SVD : 0.5152901606178535
# Mean initial score MMR : 0.5137883700120701
# Mean initial score MMR-EDC : 0.5104165549769092
# Mean initial score PI-adaptDiv : 0.5131598989236847
# Q2
# Mean initial score SVD : 0.5208888133616126
# Mean initial score MMR : 0.5183208004427062
# Mean initial score MMR-EDC : 0.5143077146500071
# Mean initial score PI-adaptDiv : 0.5190765911581205
# Q3
# Mean initial score SVD : 0.5187727863186028
# Mean initial score MMR : 0.517189764595428
# Mean initial score MMR-EDC : 0.5106321448537607
# Mean initial score PI-adaptDiv : 0.5163092870094598
# Q4
# Mean initial score SVD : 0.5208696457292024
# Mean initial score MMR : 0.5184659367760945
# Mean initial score MMR-EDC : 0.5132325249810971
# Mean initial score PI-adaptDiv : 0.5197723583496039

# %% [markdown]
# # 3. Quality vs Diversity

# %% [markdown]
# ### 3.1. All users

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot the 2D boxplots with different colors and labels
confidence_interval_2D(diversity_change_svd, qual_svd, ax, color=default_colors[0], label="SVD")
confidence_interval_2D(diversity_change_mmr, qual_mmr, ax, color=default_colors[1], label="SVD+MMR")
confidence_interval_2D(diversity_change_mmr_edc, qual_mmr_edc, ax, color=default_colors[2], label="SVD+MMR-EDC")
confidence_interval_2D(diversity_change_PI, qual_PI, ax, color=default_colors[3], label="PI-adaptDiv")

# Add a legend
ax.legend(loc='upper right', fontsize=12)
ax.set_xlabel("Consumed Diversity change", fontsize = 14)
ax.set_ylabel("Quality (Precision@N)", fontsize = 14)

plt.show()

# %% [markdown]
# ## 2.2. By quadrants

# %%
mean_diversity_baseline_Q1 = mean_diversity_all_users(Q1,'baseline')
mean_diversity_baseline_Q2 = mean_diversity_all_users(Q2,'baseline')
mean_diversity_baseline_Q3 = mean_diversity_all_users(Q3,'baseline')
mean_diversity_baseline_Q4 = mean_diversity_all_users(Q4,'baseline')

diversity_change_svd_Q1 = (get_final_diversity(Q1,'baseline') - get_initial_diversity(Q1,'baseline'))
diversity_change_svd_Q2 = (get_final_diversity(Q2,'baseline') - get_initial_diversity(Q2,'baseline'))
diversity_change_svd_Q3 = (get_final_diversity(Q3,'baseline') - get_initial_diversity(Q3,'baseline'))
diversity_change_svd_Q4 = (get_final_diversity(Q4,'baseline') - get_initial_diversity(Q4,'baseline'))

quality_svd_Q1 = initial_scores_for_users(Q1,'baseline')
quality_svd_Q2 = initial_scores_for_users(Q2,'baseline')
quality_svd_Q3 = initial_scores_for_users(Q3,'baseline')
quality_svd_Q4 = initial_scores_for_users(Q4,'baseline')
print("baseline : Done")


diversity_change_mmr_Q1 = (get_final_diversity(Q1,'mmr','lambda_0.7') - get_initial_diversity(Q1,'mmr','lambda_0.7'))
diversity_change_mmr_Q2 = (get_final_diversity(Q2,'mmr','lambda_0.7') - get_initial_diversity(Q2,'mmr','lambda_0.7'))
diversity_change_mmr_Q3 = (get_final_diversity(Q3,'mmr','lambda_0.7') - get_initial_diversity(Q3,'mmr','lambda_0.7'))
diversity_change_mmr_Q4 = (get_final_diversity(Q4,'mmr','lambda_0.7') - get_initial_diversity(Q4,'mmr','lambda_0.7'))

quality_mmr_Q1 =  (initial_scores_for_users(Q1,'mmr',f'lambda_0.7'))
quality_mmr_Q2 =  (initial_scores_for_users(Q2,'mmr',f'lambda_0.7'))
quality_mmr_Q3 =  (initial_scores_for_users(Q3,'mmr',f'lambda_0.7'))
quality_mmr_Q4 =  (initial_scores_for_users(Q4,'mmr',f'lambda_0.7'))
print("mmr : Done")

diversity_change_mmr_edc_Q1 = (get_final_diversity(Q1,'mmr_exp_div_change',parameters = 'lambda_0.9') - get_initial_diversity(Q1,'mmr_exp_div_change',parameters = 'lambda_0.9'))
diversity_change_mmr_edc_Q2 = (get_final_diversity(Q2,'mmr_exp_div_change',parameters = 'lambda_0.9') - get_initial_diversity(Q2,'mmr_exp_div_change',parameters = 'lambda_0.9'))
diversity_change_mmr_edc_Q3 = (get_final_diversity(Q3,'mmr_exp_div_change',parameters = 'lambda_0.9') - get_initial_diversity(Q3,'mmr_exp_div_change',parameters = 'lambda_0.9'))
diversity_change_mmr_edc_Q4 = (get_final_diversity(Q4,'mmr_exp_div_change',parameters = 'lambda_0.9') - get_initial_diversity(Q4,'mmr_exp_div_change',parameters = 'lambda_0.9'))

quality_mmr_edc_Q1 = initial_scores_for_users(Q1,'mmr_exp_div_change',f'lambda_0.9')
quality_mmr_edc_Q2 = initial_scores_for_users(Q2,'mmr_exp_div_change',f'lambda_0.9')
quality_mmr_edc_Q3 = initial_scores_for_users(Q3,'mmr_exp_div_change',f'lambda_0.9')
quality_mmr_edc_Q4 = initial_scores_for_users(Q4,'mmr_exp_div_change',f'lambda_0.9')
print("mmr_exp : Done")


diversity_change_PI_adaptDiv_Q1 = get_final_diversity(Q1,'adapt') - get_initial_diversity(Q1,'adapt')
diversity_change_PI_adaptDiv_Q2 = get_final_diversity(Q2,'adapt') - get_initial_diversity(Q2,'adapt')
diversity_change_PI_adaptDiv_Q3 = get_final_diversity(Q3,'adapt') - get_initial_diversity(Q3,'adapt')
diversity_change_PI_adaptDiv_Q4 = get_final_diversity(Q4,'adapt') - get_initial_diversity(Q4,'adapt')

quality_PI_adaptDiv_Q1 = initial_scores_for_users(Q1,'adapt')
quality_PI_adaptDiv_Q2 = initial_scores_for_users(Q2,'adapt')
quality_PI_adaptDiv_Q3 = initial_scores_for_users(Q3,'adapt')
quality_PI_adaptDiv_Q4 = initial_scores_for_users(Q4,'adapt')
print("adapt : Done")


# Create the figure and axis
fig, axs = plt.subplots(2, 2, figsize=(8, 8), sharex=False, sharey=False)


# Plot the 2D boxplots with different colors and labels
confidence_interval_2D(diversity_change_svd_Q1, quality_svd_Q1, axs[0,0], color=default_colors[0], label="SVD")
confidence_interval_2D(diversity_change_mmr_Q1, quality_mmr_Q1, axs[0,0], color=default_colors[1], label="SVD+MMR")
confidence_interval_2D(diversity_change_mmr_edc_Q1, quality_mmr_edc_Q1, axs[0,0], color=default_colors[2], label="SVD+MMR-EDC")
confidence_interval_2D(diversity_change_PI_adaptDiv_Q1, quality_PI_adaptDiv_Q1, axs[0,0], color=default_colors[3], label="PI-adaptDiv",ylabel="Quality (Precision@N)")

confidence_interval_2D(diversity_change_svd_Q2, quality_svd_Q2, axs[0,1], color=default_colors[0])
confidence_interval_2D(diversity_change_mmr_Q2, quality_mmr_Q2, axs[0,1], color=default_colors[1])
confidence_interval_2D(diversity_change_mmr_edc_Q2, quality_mmr_edc_Q2, axs[0,1], color=default_colors[2])
confidence_interval_2D(diversity_change_PI_adaptDiv_Q2, quality_PI_adaptDiv_Q2, axs[0,1], color=default_colors[3])

confidence_interval_2D(diversity_change_svd_Q3, quality_svd_Q3, axs[1,0], color=default_colors[0])
confidence_interval_2D(diversity_change_mmr_Q3, quality_mmr_Q3, axs[1,0], color=default_colors[1])
confidence_interval_2D(diversity_change_mmr_edc_Q3, quality_mmr_edc_Q3, axs[1,0], color=default_colors[2])
confidence_interval_2D(diversity_change_PI_adaptDiv_Q3, quality_PI_adaptDiv_Q3, axs[1,0], color=default_colors[3],ylabel="Quality (Precision@N)",xlabel="Consumed Diversity change")

confidence_interval_2D(diversity_change_svd_Q4, quality_svd_Q4, axs[1,1], color=default_colors[0])
confidence_interval_2D(diversity_change_mmr_Q4, quality_mmr_Q4, axs[1,1], color=default_colors[1])
confidence_interval_2D(diversity_change_mmr_edc_Q4, quality_mmr_edc_Q4, axs[1,1], color=default_colors[2])
confidence_interval_2D(diversity_change_PI_adaptDiv_Q4, quality_PI_adaptDiv_Q4, axs[1,1], color=default_colors[3],xlabel="Consumed Diversity change")

# Add a legend
ax.legend(loc='upper right', fontsize=12)
#fig.set_xlabel("Diversity change", fontsize = 14)
fig.legend(loc='upper right', bbox_to_anchor=(0.72, 0.96),ncol = 2)
# Out:
# baseline : Done
# mmr : Done
# mmr_exp : Done
# adapt : Done
